# %% [markdown]
# <a href="https://colab.research.google.com/github/swastika211106/hguytu/blob/main/cobaa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hallo")
# Out:
# hallo
